# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/lenna.png')
r,g,b = cv2.split(img)

# %%
gs = 0.298*r + 0.587*g + 0.114*b
cv2_imshow(gs)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F560FA06D50>
